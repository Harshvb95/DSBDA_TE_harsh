# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a=pd.read_csv(r"C:\Users\Janhavi\OneDrive\Desktop\heart.csv")

# %%
a.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
a
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
#pie chart
colors=('red','yellow','blue','green')
a['cp'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
labels = '0','1','2','3'
sizes= a['cp'].value_counts()

# %%
plt.pie(sizes,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title(' cp values')
# Out:
# Text(0.5, 1.0, ' cp values')

# %%
plt.hist(a['age'],color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#pair plt
sns.set(style='ticks')

# %%
sns.pairplot(a ,vars=['age','target','cp'])

# %%
import matplotlib.pyplot as plt

# Extracting data
chol = a.iloc[:20, 4]  # Select all rows for the 'chol' column
age = a.iloc[:20,0]  # Select all rows for the 'age' column


# Plot
plt.figure(figsize=(10, 6))
plt.plot(age, chol, marker='o', linestyle='-')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Cholesterol Level')
plt.title('Cholesterol Level vs. Age')

# Show plot
plt.grid(True)
plt.show()

# %%
#Scatter Plot
x = a['age']
y = a['chol']
plt.scatter(x,y,color='blue')
plt.xlabel('age')
plt.ylabel('cholestrol')
# Out:
# Text(0, 0.5, 'cholestrol')

# %%
#Heat Map
corr=a.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True)
plt.show()

# %%
#box plot
import matplotlib.pyplot as plt

# Plot box plot for cholesterol level
plt.figure(figsize=(8, 6))  # Set the figure size
plt.boxplot(a['chol'], vert=False)    # Plot the box plot for cholesterol level horizontally
plt.title('Box Plot of Cholesterol Level')
plt.xlabel('Cholesterol Level')
plt.show()
